# %%
import pandas as pd

# %%
named_df = pd.read_csv("./2012-01-2025-05-overdoses-named0419.csv")
# Out:
# /tmp/ipykernel_2159236/2530694313.py:1: DtypeWarning: Columns (7,10,36,39,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   named_df = pd.read_csv("./2012-01-2025-05-overdoses-named0419.csv")

# %%
named_df['FirstName'].value_counts()
# Out:
# FirstName
# MICHAEL    443
# JOSE       361
# DAVID      360
# ROBERT     311
# JAMES      269
#           ...
# ISADORE      1
# HELENE       1
# DYLAN        1
# RYANN        1
# SHABRE       1
# Name: count, Length: 4679, dtype: int64
